# %% [markdown]
# 1. Explain the difference between Relative, Absolute and Mixed Cell Referencing.
#
#
# *   Relative Reference
#
#     ->A relative reference changes automatically when you copy the formula to another cell.
#
#     ->example:if you write in C1:A1+B1  AND drag it down to C2;then it becomes A2+B2
#
#
#
#
# * Absolute Reference
#
#     ->An absolute reference does NOT change when copied.
#
#     ->Dollar ($) sign is used before column and row.
#
#     ->Both row and column are locked.
#
#
#
#
# * Mixed Reference
#
#     ->Only one part (row or column) is fixed.
#
#   There are two types:
#
#     -> $A1 → Column fixed, row changes
#
#     -> A$1 → Row fixed, column changes
#     Example:$A1*B$1
#
#     ->Either row OR column is locked.
#
#     ->Used when: Creating multiplication tables or structured data tables.

# %% [markdown]
# 2. Write a formula to calculate the total sales of Car and Bicyle only only.
#
# ![Screenshot 2026-02-13 214521.png](data:image/png;base64,...)

# %% [markdown]
# 3.Using the data below, write a formula to calculate the average sales of items priced above 100 but less than 300.
#
# ![Screenshot 2026-02-13 215337.png](data:image/png;base64,...)

# %% [markdown]
# 4.Count how many customer names are recorded.
#
# ![Screenshot 2026-02-13 220207.png](data:image/png;base64,...)

# %% [markdown]
# 5.Calculate the Total Sales for each row using a formula.
#
# ![Screenshot 2026-02-13 223934.png](data:image/png;base64,...)

# %% [markdown]
# 6.Calculate the total sales of Notebooks in the North region only.
#
# ![Screenshot 2026-02-13 224744.png](data:image/png;base64,...)

# %% [markdown]
# 7.Create a column chart showing total sales by product.
#
# ![Screenshot 2026-02-13 225355.png](data:image/png;base64,...)

# %% [markdown]
# 8.Insert a line chart showing daily sales trend
# ![Screenshot 2026-02-13 230002.png](data:image/png;base64,...)
