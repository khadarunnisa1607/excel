# %% [markdown]
# 1. Write a formuls to check if the marks in celll B2 are greater than or equal to 40. If yes return "pass",other wise "Fail".
# ![Screenshot 2026-02-24 154545.png](data:image/png;base64,...)

# %% [markdown]
# 2. company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a
# formula to calculate whether the employee will get a bonus or not .
#
#
# ![Screenshot 2026-02-24 155658.png](data:image/png;base64,...)

# %% [markdown]
# 3.Write a nested formula.
# If marks in B2 are >=90->"A",>=75->"B",>=50->"C",other wise "fail".
# ![Screenshot 2026-02-24 160542.png](data:image/png;base64,...)

# %% [markdown]
# 4.Find the Department of EMPLOYEE ID=E103.Also explain which Lookup function is used and why?
# ![Screenshot 2026-02-24 161126.png](data:image/png;base64,...)
#
#
#
#
#
# Here we use VLOOKUP;
#  Because:
#  1) The employee id is in the first column.
#  2) we are searching vertically
#  3)we want to return a value from column to right.

# %% [markdown]
# 5.A company has set the following commission structure for its sales team:
#
# If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
#
# ![Screenshot 2026-02-24 162343.png](data:image/png;base64,...)

# %% [markdown]
# 6.The HR department maintains the following leave records of employees:onus or not .
#
#
# ->Write an IF function to check
#
# ->whether an employee has Exceeded their allowed leave balance.
#
# ->If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# ->Otherwise, display "OK".
#
# ![Screenshot 2026-02-24 162944.png](data:image/png;base64,...)

# %% [markdown]
# 7.Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# ![Screenshot 2026-02-24 163156.png](data:image/png;base64,...)

# %% [markdown]
# 8. se the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
# ![Screenshot 2026-02-24 163518.png](data:image/png;base64,...)
